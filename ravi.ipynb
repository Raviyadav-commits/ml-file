# %%
import pandas as pd 
import numpy as np 
#python libraries

# %%
data=pd.read_csv('data.csv')

# %%
data
#represents dataset
# Out:
#    example          sky airtemp- humadity    wind  water   forecast enjoysport
# 0        1        sunny     warm   normal  strong   warm       same        yes
# 1        2        sunny     warm     high  strong   warm     change         no
# 2        3        rainy     cold     high  strong   warm     change         no
# 3        4        sunny     warm     high  strong   cool     change        yes

# %%
concepts = np.array(data)[:,:-1]

# %%
concepts
# Out:
# array([[1, '      sunny', 'warm', 'normal', 'strong', 'warm', 'same'],
#        [2, '      sunny', 'warm', 'high', 'strong', 'warm', '  change'],
#        [3, '      rainy', 'cold', 'high', 'strong', 'warm', '  change'],
#        [4, '     sunny', 'warm', 'high', 'strong', ' cool', '   change']],
#       dtype=object)

# %%
target = np.array(data)[:,-1]

# %%
target
# Out:
# array(['      yes', '    no', '    no', '    yes'], dtype=object)

# %%
def train(con, tar):
    for i, val in enumerate(tar):
        if val == 'yes':
            specific_h=con[i].copy()
            break
            for i, val in enumerate(con):
             if tar[i]=='yes':
              for x in range (len(specific_h)):
                if val[x] !=specific_h[x]:
                    specific_h[x]='?'
                else: 
                    pass
                    return specific_h

# %%
print(train(concepts,target))
# Out:
# None
